# %%
# importing the libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
ted_url = "https://www.ted.com/talks/quick-list?page=1" # Taking the first page of the ted talks url
ted_talks_content = requests.get(ted_url)

# %%
soup = BeautifulSoup(ted_talks_content.content , 'html.parser')

# %%
def scraper(url):
    current_page = soup.find('span', attrs={'class':'pagination__item pagination__current'}).get_text()
    print(f"Scraping the Page : {current_page}")
    
    # df = pd.DataFrame()
    
    # # getting the column names for the dataframe from the ted talks
    # #def get_column():
    # get_column_table = soup.find('div', attrs={'class':'row m2 quick-list__labels'})
    # for col in get_column_table:
    #     col = col.get_text(strip=True)
    #     df[col] = []
    # del df['Download']
    
    # Find all the div elements with class 'col-xs-6 title' and 'col-xs-2 event'
    title_elements = soup.find_all('div', class_='col-xs-6 title')
    event_elements = soup.find_all('div', class_='col-xs-2 event')

    # Initialize empty lists for 'Title' and 'Event'
    title = []
    event = []

    # Extract the values from these div elements and append to the respective lists
    for title_element, event_element in zip(title_elements, event_elements):
        title_span = title_element.find('span', {'class': 'l3'})
        event_span = event_element.find('a')
        if title_span and event_span:
            title_text = title_span.get_text(strip=True)
            event_text = event_span.get_text(strip=True)
            title.append(title_text)
            event.append(event_text)

    # Create a DataFrame with 'Title' and 'Event' columns
    data = {'Title': title, 'Event': event}
    df = pd.DataFrame(data)


    get_current_page =  soup.find('span', class_ = 'pagination__item pagination__current').get_text()
    print(get_current_page)
    if soup.find('a', 'pagination__next pagination__flipper pagination__link').get_text() == "Next":
        updated_url = ted_url.split('=')[0] +'='+ str(int(get_current_page)+1)
    else :
        
    print(updated_url)

    return df

# %%
d = scraper(ted_url)
# Out:
# Scraping the Page : 1

# %%
d
# Out:
# Empty DataFrame
# Columns: [, Published, Title, Event, Duration]
# Index: []

# %%
# checking the first page of the ted talks
page_content = soup.find('div', class_ ='row quick-list__container')
page_content.find()

# %%
# Find all the div elements with class 'col-xs-6 title' and 'col-xs-2 event'
title_elements = soup.find_all('div', class_='col-xs-6 title')
event_elements = soup.find_all('div', class_='col-xs-2 event')

# Initialize empty lists for 'Title' and 'Event'
title = []
event = []

# Extract the values from these div elements and append to the respective lists
for title_element, event_element in zip(title_elements, event_elements):
    title_span = title_element.find('span', {'class': 'l3'})
    event_span = event_element.find('a')
    if title_span and event_span:
        title_text = title_span.get_text(strip=True)
        event_text = event_span.get_text(strip=True)
        title.append(title_text)
        event.append(event_text)

# Create a DataFrame with 'Title' and 'Event' columns
data = {'Title': title, 'Event': event}
df = pd.DataFrame(data)

# Print the DataFrame
print(df)
# Out:
#                                                 Title                 Event
# 0               TED-Ed: How to overcome your mistakes                TED-Ed
# 1   Gabrielle Novacek: To support people at work, ...               TED@BCG
# 2   Annie Rauwerda: The joy of learning random thi...              TEDxUofM
# 3       Payton M. Wilkins: Unions for climate action!  TED Countdown Summit
# 4   Alex Soojung-Kim Pang: How rest can make you b...       The Way We Work
# 5   Shannon Odell: Does recycling your plastic act...                TED-Ed
# 6     Aisha Nyandoro: What does "wealth" mean to you?         TEDWomen 2023
# 7   Dasha Navalnaya: Lessons from my father, Alexe...         TEDWomen 2023
# 8               Sarah Kay: "Miles from Any Shoreline"               TED2023
# 9          TED-Ed: 3 tips on how to study effectively                TED-Ed
# 10  Asmeret Asefaw Berhe: We actually have a shot ...  TED Countdown Summit
# 11  Piyachart Phiromswad: The tech we need to figh...               TED2023
# 12  Ian Bremmer: The Israel-Hamas war — and what i...            TED Studio
# 13  Nadia Frontier: Surviving the coldest place on...                TED-Ed
# 14  Krista Tippett: 3 practices for wisdom and who...               TED2023
# 15  Mark T. Rivera: 3 ways to better connect with ...       The Way We Work
# 16  Nicos Marcou: Work has changed. Why haven't re...           TEDxBayonne
# 17  Amy Powney: How to fix fashion and protect the...  TED Countdown Summit
# 18  Carolyn Beans: What would happen if everyone s...                TED-Ed
# 19  Carlos Rodríguez-Pastor: How business can driv...               TED2023
# 20  Tavares Strachan: The Encyclopedia of Invisibi...               TED2023
# 21  Douglas MacLean: Ethical dilemma: What makes l...                TED-Ed
# 22  Jordan Dinwiddie: 10 lessons I learned from be...          TEDxPortland
# 23  Shahar Erez: How to build a freelance career t...       The Way We Work
# 24  Jennifer D. Sciubba: The truth about human pop...               TED2023
# 25  Ramón Méndez Galain: This country runs on 98 p...  TED Countdown Summit
# 26  Gabriel Prieto: The conspiracy to take down th...                TED-Ed
# 27  Anna Greka: The world's rarest diseases — and ...               TED2023
# 28  Robin Buckley: Why I gave my teenage daughter ...        TEDxPortsmouth
# 29  Maria Elena De Obaldia: Do mosquitos actually ...                TED-Ed
# 30  Jennifer Doudna: CRISPR's next advance is bigg...               TED2023
# 31  Michelle R. Weise: 4 tips to future-proof your...       The Way We Work
# 32  Melissa Villaseñor: How I found myself -- by i...               TED2023
# 33  Hannah Ritchie: Are we the last generation -- ...               TED2023
# 34  Carly Anne York: Want to know if you're pregna...                TED-Ed
# 35  Josephine Philips: The simple solution to fast...  TED Countdown Summit

# %%
df
# Out:
#    Published                                              Title  \
# 0        N/A                                              Title
# 1        N/A              TED-Ed: How to overcome your mistakes
# 2        N/A  Gabrielle Novacek: To support people at work, ...
# 3        N/A  Annie Rauwerda: The joy of learning random thi...
# 4        N/A      Payton M. Wilkins: Unions for climate action!
# ..       ...                                                ...
# 69       N/A                                                N/A
# 70       N/A                                                N/A
# 71       N/A                                                N/A
# 72       N/A                                                N/A
# 73       N/A                                                N/A
#
#                    Event   Duration
# 0                  Event  Published
# 1                 TED-Ed   Duration
# 2                TED@BCG   Oct 2023
# 3               TEDxUofM
# 4   TED Countdown Summit   Oct 2023
# ..                   ...        ...
# 69                   N/A
# 70                   N/A   Sep 2023
# 71                   N/A
# 72                   N/A   Sep 2023
# 73                   N/A
#
# [74 rows x 4 columns]

# %%
df.head(40)
# Out:
#    Published                                              Title  \
# 0        N/A                                              Title
# 1        N/A              TED-Ed: How to overcome your mistakes
# 2        N/A  Gabrielle Novacek: To support people at work, ...
# 3        N/A  Annie Rauwerda: The joy of learning random thi...
# 4        N/A      Payton M. Wilkins: Unions for climate action!
# 5        N/A  Alex Soojung-Kim Pang: How rest can make you b...
# 6        N/A  Shannon Odell: Does recycling your plastic act...
# 7        N/A    Aisha Nyandoro: What does "wealth" mean to you?
# 8        N/A  Dasha Navalnaya: Lessons from my father, Alexe...
# 9        N/A              Sarah Kay: "Miles from Any Shoreline"
# 10       N/A         TED-Ed: 3 tips on how to study effectively
# 11       N/A  Asmeret Asefaw Berhe: We actually have a shot ...
# 12       N/A  Piyachart Phiromswad: The tech we need to figh...
# 13       N/A  Ian Bremmer: The Israel-Hamas war — and what i...
# 14       N/A  Nadia Frontier: Surviving the coldest place on...
# 15       N/A  Krista Tippett: 3 practices for wisdom and who...
# 16       N/A  Mark T. Rivera: 3 ways to better connect with ...
# 17       N/A  Nicos Marcou: Work has changed. Why haven't re...
# 18       N/A  Amy Powney: How to fix fashion and protect the...
# 19       N/A  Carolyn Beans: What would happen if everyone s...
# 20       N/A  Carlos Rodríguez-Pastor: How business can driv...
# 21       N/A  Tavares Strachan: The Encyclopedia of Invisibi...
# 22       N/A  Douglas MacLean: Ethical dilemma: What makes l...
# 23       N/A  Jordan Dinwiddie: 10 lessons I learned from be...
# 24       N/A  Shahar Erez: How to build a freelance career t...
# 25       N/A  Jennifer D. Sciubba: The truth about human pop...
# 26       N/A  Ramón Méndez Galain: This country runs on 98 p...
# 27       N/A  Gabriel Prieto: The conspiracy to take down th...
# 28       N/A  Anna Greka: The world's rarest diseases — and ...
# 29       N/A  Robin Buckley: Why I gave my teenage daughter ...
# 30       N/A  Maria Elena De Obaldia: Do mosquitos actually ...
# 31       N/A  Jennifer Doudna: CRISPR's next advance is bigg...
# 32       N/A  Michelle R. Weise: 4 tips to future-proof your...
# 33       N/A  Melissa Villaseñor: How I found myself -- by i...
# 34       N/A  Hannah Ritchie: Are we the last generation -- ...
# 35       N/A  Carly Anne York: Want to know if you're pregna...
# 36       N/A  Josephine Philips: The simple solution to fast...
# 37       N/A                                                N/A
# 38       N/A                                                N/A
# 39       N/A                                                N/A
#
#                    Event   Duration
# 0                  Event  Published
# 1                 TED-Ed   Duration
# 2                TED@BCG   Oct 2023
# 3               TEDxUofM
# 4   TED Countdown Summit   Oct 2023
# 5        The Way We Work
# 6                 TED-Ed   Oct 2023
# 7          TEDWomen 2023
# 8          TEDWomen 2023   Oct 2023
# 9                TED2023
# 10                TED-Ed   Oct 2023
# 11  TED Countdown Summit
# 12               TED2023   Oct 2023
# 13            TED Studio
# 14                TED-Ed   Oct 2023
# 15               TED2023
# 16       The Way We Work   Oct 2023
# 17           TEDxBayonne
# 18  TED Countdown Summit   Oct 2023
# 19                TED-Ed
# 20               TED2023   Oct 2023
# 21               TED2023
# 22                TED-Ed   Oct 2023
# 23          TEDxPortland
# 24       The Way We Work   Oct 2023
# 25               TED2023
# 26  TED Countdown Summit   Oct 2023
# 27                TED-Ed
# 28               TED2023   Oct 2023
# 29        TEDxPortsmouth
# 30                TED-Ed   Oct 2023
# 31               TED2023
# 32       The Way We Work   Oct 2023
# 33               TED2023
# 34               TED2023   Oct 2023
# 35                TED-Ed
# 36  TED Countdown Summit   Oct 2023
# 37                   N/A
# 38                   N/A   Oct 2023
# 39                   N/A

# %%
get_current_page =  soup.find('span', class_ = 'pagination__item pagination__current').get_text()
print(get_current_page)
if soup.find('a', 'pagination__next pagination__flipper pagination__link').get_text() == "Next":
    updated_url = ted_url.split('=')[0] +'='+ str(int(get_current_page)+1)
print(updated_url)
# Out:
# 56
# https://www.ted.com/talks/quick-list?page=57

# %% [markdown]
# #### The Ted Website is not allowing to scrape all the pages but it can go to some limit and then stop. so we tried repeating the scraper for multiple times through our manual page number given and it scrapes the data through it

# %%
def scraper(url):
    all_data = pd.DataFrame()  # Create an empty DataFrame to store all data
    page = 151
    
    while True:
        # Create the URL for the current page
        current_url = f"{url}?page={page}"
        
        # Send a GET request to the URL
        response = requests.get(current_url)
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Find all the div elements with class 'col-xs-6 title' and 'col-xs-2 event'
        title_elements = soup.find_all('div', class_='col-xs-6 title')
        event_elements = soup.find_all('div', class_='col-xs-2 event')

        # Initialize empty lists for 'Title' and 'Event'
        title = []
        event = []

        # Extract the values from these div elements and append to the respective lists
        for title_element, event_element in zip(title_elements, event_elements):
            title_span = title_element.find('span', {'class': 'l3'})
            event_span = event_element.find('a')
            if title_span and event_span:
                title_text = title_span.get_text(strip=True)
                event_text = event_span.get_text(strip=True)
                title.append(title_text)
                event.append(event_text)

        # Create a DataFrame with 'Title' and 'Event' columns for the current page
        data = {'Title': title, 'Event': event}
        df = pd.DataFrame(data)
        
        # Concatenate the data to the main DataFrame
        all_data = pd.concat([all_data, df], ignore_index=True)
        
        print(f"Scraped data from Page {page}")
        
        # Check if the "Next" option is available
        next_button = soup.find('a', class_='pagination__next pagination__flipper pagination__link')
        if not next_button:
            break  # Exit the loop if there is no "Next" button
        
        page += 1  # Move to the next page

    return all_data

# Example usage
ted_url = "https://www.ted.com/talks/quick-list"  # Replace with your TED Talks URL
result_df = scraper(ted_url)

# Print the resulting DataFrame
print(result_df)
# Out:
# Scraped data from Page 151
# Scraped data from Page 152
# Scraped data from Page 153
# Scraped data from Page 154
# Scraped data from Page 155
# Scraped data from Page 156
# Scraped data from Page 157
# Scraped data from Page 158
# Scraped data from Page 159
# Scraped data from Page 160
# Scraped data from Page 161
# Scraped data from Page 162
# Scraped data from Page 163
# Scraped data from Page 164
# Scraped data from Page 165
# Scraped data from Page 166
# Scraped data from Page 167
# Scraped data from Page 168
# Scraped data from Page 169
# Scraped data from Page 170
# Scraped data from Page 171
#                                                  Title     Event
# 0              Nalini Nadkarni: Life science in prison   TED2010
# 1    Ellen  Gustafson: Obesity + hunger = 1 global ...  TEDxEast
# 2    Benoit Mandelbrot: Fractals and the art of rou...   TED2010
# 3    Mitchell Joachim: Don't build your home, grow it!   TED2010
# 4            Carter Emmart: A 3D atlas of the universe   TED2010
# ..                                                 ...       ...
# 718      Hans Rosling: The best stats you've ever seen   TED2006
# 719      Sir Ken Robinson: Do schools kill creativity?   TED2006
# 720                 Majora Carter: Greening the ghetto   TED2006
# 721                      David Pogue: Simplicity sells   TED2006
# 722               Al Gore: Averting the climate crisis   TED2006
#
# [723 rows x 2 columns]

# %%
result_df.tail()
# Out:
#                                                   Title             Event
# 1003  Joan Blades and John Gable: Free yourself from...     TEDWomen 2017
# 1004  Alejandro Nespral: Hablemos de la muerte con l...     TEDxBariloche
# 1005  Xavier De Kestelier: Adventures of an interpla...        TEDxLeuven
# 1006  Gautam Bhan: A bold plan to house 100 million ...   TED Talks India
# 1007  Tal Zaks: The disease-eradicating potential of...  TEDxBeaconStreet

# %%
data_till_28 = result_df

# %%
data_till_28.tail()
# Out:
#                                                   Title            Event
# 1003  Dan Goods: How NASA invented a ventilator for ...      TEDxStLouis
# 1004  Masako Tamaki: Can you be awake and asleep at ...           TED-Ed
# 1005  Sarah Ellis and Helen Tupper: The best career ...  TEDxLondonWomen
# 1006  Marianne Schwarz: What happens to your brain d...           TED-Ed
# 1007  Nadya Bartol: Better cybersecurity starts with...          TED@BCG

# %%
data_from_28_to_57 = result_df

# %%
data_from_28_to_57.tail()
# Out:
#                                                   Title  \
# 1039  Moriba Jah: The world's first crowdsourced spa...
# 1040  Camille Defrenne and Suzanne Simard: The secre...
# 1041  Megan Parker: How dogs help with conservation ...
# 1042  Gregory Berns: What emotions look like in a do...
# 1043  Barbara Sherman: How to read a dog's body lang...
#
#                               Event
# 1039                        TED2019
# 1040                         TED-Ed
# 1041                TEDxJacksonHole
# 1042                    TEDxAtlanta
# 1043  TEDxSandhillsCommunityCollege

# %%
data_from_57_to_85 = result_df

# %%
data_from_85_to_116 = result_df

# %%
data_from_117_to_151 = result_df

# %%
data_from_151_to_171  = result_df

# %%
dfs = [data_till_28 , data_from_28_to_57 , data_from_57_to_85 , data_from_85_to_116 , data_from_117_to_151 , data_from_151_to_171]

ted_talks_df = pd.concat(dfs , ignore_index=True)

# %%
ted_talks_df
# Out:
#                                                   Title                 Event
# 0                 TED-Ed: How to overcome your mistakes                TED-Ed
# 1     Gabrielle Novacek: To support people at work, ...               TED@BCG
# 2     Annie Rauwerda: The joy of learning random thi...              TEDxUofM
# 3         Payton M. Wilkins: Unions for climate action!  TED Countdown Summit
# 4     Alex Soojung-Kim Pang: How rest can make you b...       The Way We Work
# ...                                                 ...                   ...
# 6154      Hans Rosling: The best stats you've ever seen               TED2006
# 6155      Sir Ken Robinson: Do schools kill creativity?               TED2006
# 6156                 Majora Carter: Greening the ghetto               TED2006
# 6157                      David Pogue: Simplicity sells               TED2006
# 6158               Al Gore: Averting the climate crisis               TED2006
#
# [6159 rows x 2 columns]

# %%
170*36
# Out:
# 6120

# %%
ted_talks_df.to_csv("Ted_Talks_Titles.csv")

# %%
import markovify

df = pd.read_csv('Ted_Talks_Titles.csv')

content = df['Title']

# %%
print(content[:10])
# Out:
# 0                TED-Ed: How to overcome your mistakes
# 1    Gabrielle Novacek: To support people at work, ...
# 2    Annie Rauwerda: The joy of learning random thi...
# 3        Payton M. Wilkins: Unions for climate action!
# 4    Alex Soojung-Kim Pang: How rest can make you b...
# 5    Shannon Odell: Does recycling your plastic act...
# 6      Aisha Nyandoro: What does "wealth" mean to you?
# 7    Dasha Navalnaya: Lessons from my father, Alexe...
# 8                Sarah Kay: "Miles from Any Shoreline"
# 9           TED-Ed: 3 tips on how to study effectively
# Name: Title, dtype: object

# %%
text_model = markovify.Text(content)

# %%
text_model.make_sentence()
# Out:
# 'Pierre Barreau: How AI is just beginning'

# %%
for i in range(5):
    print(text_model.make_short_sentence(max_chars=400))
# Out:
# Jamila Raqib: The secret society of the future
# Heidi M. Sosik: The discoveries awaiting us in the life of an extinct species
# Vinu Daniel: The beauty of human history and build trust
# William T. Taylor: How to practice safe sexting
# Jimmy Wales: The birth of the Kingdom of Kush?

# %%
content.isin(['TED-Ed: How to overcome your mistakes']).sum()
# Out:
# 1

# %%
title = 'TED-Ed: 3 tips on how to study effectively'
title.split(':')[1].strip()
# Out:
# '3 tips on how to study effectively'

# %%
new_titles_df = pd.DataFrame({'Title' : []})
titles = []
for title in df['Title']:
    title = title.split(':')[1].strip()
    titles.append(title)

new_titles_df['Title'] = titles

# %%
new_titles_df
# Out:
#                                                   Title
# 0                         How to overcome your mistakes
# 1     To support people at work, focus on needs — no...
# 2        The joy of learning random things on Wikipedia
# 3                            Unions for climate action!
# 4              How rest can make you better at your job
# ...                                                 ...
# 6154                    The best stats you've ever seen
# 6155                        Do schools kill creativity?
# 6156                                Greening the ghetto
# 6157                                   Simplicity sells
# 6158                        Averting the climate crisis
#
# [6159 rows x 1 columns]

# %%
new_content = new_titles_df['Title']

model = markovify.Text(new_content)

# %%
#check if the generated content available in the corpus

for i in range(10):
    generated_title = model.make_short_sentence(max_chars=1000)
    if new_content.isin([generated_title]).sum() == 1:
        print(True)
    else:
        print(generated_title)
# Out:
# The painter and the fall of the future, and other thoughts on capital in the face of a surveillance state
# How we'll predict the next great city?
# The ancient ingenuity of water a day
# At what moment are you creating for yourself?
# How moms shape the near win
# The symbols of systemic racism in the deep ocean
# Planning for the world
# What is the fastest way to hear
# A tool to fix a government
# The state of the Lakota Empire

# %%
model.make_sentence_with_start('What')
# Out:
# 'What gardening taught me about living fully'

# %%
for i in range(10):
    generated_title = model.make_short_sentence(max_chars=50, tries = 50)
    if new_content.isin([generated_title]).sum() == 1:
        print(True)
    else:
        print(generated_title)
# Out:
# 3 lessons on success from an Olympic gymnast
# You don't have to go to escape gravity?
# 3 ways to share math with computers
# How to be a better world
# The surprising solution to fast fashion
# Why books are here to stay calm under pressure
# The power of quadcopters
# The myth of government
# 5 keys to a healthier life
# The power of diverse thought

# %%
# machine learning paper title generation

with open('D:\THWS MAI 2023\Semester-2\Semantic Data Processing\Group Tasks\Markovify Project\ML_Paper_Titles.txt') as s:
    title_text = s.read()

ml_title_model = markovify.NewlineText(title_text , )

# %%
for i in range(4):
    ml_title_model.make_short_sentence(max_chars=300)

# %%
for i in range(100):
    title = ml_title_model.make_sentence(tries = 10)
    print(title)
# Out:
# Power to the wrapper.
# Balancing exploration and exploitation: A new platform for distributed machine learning approaches
# A survey of active machine learning with big data analytics in plants
# Transferability in machine learning workbench for data center optimization
# Forest biomass estimation from airborne LiDAR data using machine learning accuracy with high dimensional spectral data
# Active learning with cooperation
# Survey of review spam detection using SVM and other protein sorting signals
# None
# Markov games as a framework for detecting phishing web sites
# Entanglement-based machine learning …
# Improved base calling for the classification restricted boltzmann machine
# Image analysis and machine learning architecture for optimizing the hyperparameters of machine learning to optimize multicore performance
# Machine learning for robust microarray data for cancer classification
# A machine learning in cybersecurity
# Hotspot detection based on machine learning for activity recognition: hip versus wrist data
# Improve computer-aided diagnosis with machine learning on gene expression data for cancer classification
# Machine learning and optimization perspective
# Neural machine translation by jointly learning to enhance the effectiveness of similarity searching
# Comparing machine learning approach to software fault-proneness prediction
# Introduction to machine learning in medical applications
# Factorizing yago: scalable machine learning using gaussian fields and harmonic functions
# A survey on machine-learning techniques in machine learning
# Data mining and machine learning classifiers for mobile security
# Diffuse large B-cell lymphoma outcome prediction by machine learning based prediction systems
# Three-objective genetics-based machine learning to detect cyberbullying
# SVD-based quality metric for machine learning techniques
# Bacterial species identification from shotgun proteomics datasets
# Alternating minimization and Boltzmann machine learning and rule induction
# An empirical study of statistical techniques and performance measures for genetics-based machine learning: comparing a correlation-based filter approach to pronoun resolution in spoken dialogue systems
# Sparse greedy matrix approximation for machine learning approach for tracing regulatory codes to product specific requirements
# Machine learning and data mining in the Hadoop ecosystem
# An application of machine learning to agricultural data
# Finding nature's missing ternary oxide compounds using machine learning algorithms: implications for genomic studies
# Eigentransfer: a unified framework for machine learning algorithms fail in misuse detection on the web
# Automatic text summarization using a new synthesis
# An active role for machine learning with R
# An empirical study of distance-based machine learning
# Estimating soil moisture using remote sensing image analysis with GIS data
# An empirical comparison of two learning algorithms fail in misuse detection on KDD intrusion detection
# Comparative experiments on disambiguating word senses: An illustration of the behavior of several methods for balancing machine learning
# A machine learning approach for predicting DNA-binding proteins
# A first course in machine learning models for machine learning to predict poverty
# Support vector machine learning-based text categorization
# The cross-entropy method: a unified approach to twitter user classification
# A novel ensemble machine learning approach for tracing regulatory codes to patient encounters using example-based and machine learning library for optimizing web search engines
# Genetic algorithms as a tool for feature selection of discrete and numeric class machine learning
# Drug repositioning: a machine-learning approach for microRNA target predictions—machine learning for molecular and materials science
# Comparing machine learning techniques
# Drug design by machine learning: From theory to algorithms
# Distributed GraphLab: a framework for transfer learning
# Bioinformatics: the machine learning with multiple classifiers
# Machine learning approaches for prediction of treatment outcome in depression: a machine learning on encrypted data
# Machine learning: The use of machine learning to anomaly detection
# Introduction to machine learning systems: Beyond learning algorithms for traffic sign recognition
# Optimization method based extreme learning machine for regression with missing data
# Estimating pixel-scale land cover classification from satellite data
# Optical coherence tomography machine learning be secure?
# A literature survey of techniques for automatic determination of rules to control locomotion
# A machine learning techniques for the semantic web
# Crystal structure representations for text and document mining
# Machine learning in astronomy
# Machine learning for android malware detection at scale
# Incremental and decremental support vector machine for multi-classification
# Combined optimization of feature selection of discrete and numeric class machine learning in scheduling
# Toward harnessing user feedback for machine learning: from phenomena to black-box attacks against the Asirra CAPTCHA
# Machine learning on multicore
# Machine learning with applications to biology
# A fast pruned-extreme learning machine for regression with missing data
# Classes of kernels for machine learning algorithms for text categorization
# Predicting multiple metrics for queries: Better decisions enabled by machine learning: comparing a correlation-based filter approach to automated negotiation and prospects
# Machine learning on multicore
# Using machine learning for better Web browsing
# The elements of statistical techniques and drug design
# A systematic review of classification techniques
# Ensemble methods in machine learning system for learning from imbalanced data sets
# Applications of machine learning approach
# A study of machine-learning methods for machine learning: An early draft of a general machine learning methods on microarray gene expression profiling and supervised machine learning
# Detecting stealthy false data injection using machine learning based botnet detection using real-time connectivity graph based traffic features
# Cross-trial prediction of treatment outcome in depression: a machine learning approach to building domain-specific search engines with machine learning
# SVD-based quality metric for machine learning based software development effort
# Machine learning approach for classifying android applications using machine learning
# Machine learning for linked data
# Multivariate analysis of fMRI time series: classification and prediction in medicine—beyond the peak of inflated expectations
# Waffles: A machine learning based research compiler
# Machine learning in health care
# Making machine learning be secure?
# Introduction to machine learning: The use of atoms and their bond connectivities to predict the effects of single nucleotide polymorphisms on protein function
# Detection of phishing attacks: A machine learning architecture for intelligent support of conflict resolution
# A study on several machine-learning methods for predicting properties of inorganic materials
# Machine learning in parallel
# An empirical comparison of machine learning models via machine-learning algorithms
# Tensorflow: Large-scale machine learning system for learning from examples based on machine learning approach
# Structure-activity relationships derived by machine learning approach for the semantic web
# Sparse Bayesian learning and hypertext
# Introduction to statistical learning via polyhedral concave minimization
# Quantum-enhanced machine learning techniques for the prediction of linear B‐cell epitopes on proteins
# Machine learning based research compiler
# Student modeling and machine learning and its application to large-scale machine learning approaches to power-system security assessment
# Natural Language Annotation for Machine Learning: the system Asium
# Text categorization with support vector machine learning and sunspot associations
